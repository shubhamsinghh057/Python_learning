# %%
import json

# %%
d = {"name": "Shubham", "age": 24, "education": None}

# %%
data = json.dumps(d)

# %%
data
# Out:
# '{"name": "Shubham", "age": 24, "education": null}'

# %%
json.loads(data)
# Out:
# {'name': 'Shubham', 'age': 24, 'education': None}

# %%
import requests

url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "imdb-top-100-movies.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'rank': 1, 'title': 'The Shawshank Redemption', 'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@', 'genre': ['Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'rating': '9.3', 'id': 'top1', 'year': 1994, 'imdbid': 'tt0111161', 'imdb_link': 'https://www.imdb.com/title/tt0111161'}, {'rank': 2, 'title': 'The Godfather', 'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.', 'imag
# ...

# %%
data = response.json()

# %%
i = 0
n = len(data)
while i < n:
    print(data[i]["title"])
    i += 1
# Out:
# The Shawshank Redemption
# The Godfather
# The Dark Knight
# The Godfather Part II
# 12 Angry Men
# Schindler's List
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# The Lord of the Rings: The Fellowship of the Ring
# The Good, the Bad and the Ugly
# Forrest Gump
# Fight Club
# The Lord of the Rings: The Two Towers
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# The Matrix
# Goodfellas
# Spider-Man: Across the Spider-Verse
# Interstellar
# One Flew Over the Cuckoo's Nest
# Se7en
# It's a Wonderful Life
# Seven Samurai
# The Silence of the Lambs
# Saving Private Ryan
# City of God
# Life Is Beautiful
# The Green Mile
# Star Wars: Episode IV - A New Hope
# Terminator 2: Judgment Day
# Spirited Away
# Oppenheimer
# Harakiri
# Back to the Future
# The Pianist
# Psycho
# Parasite
# Gladiator
# The Lion King
# Léon: The Professional
# American History X
# The Departed
# Whiplash
# The Prestige
# The Usual Suspects
# Grave of the Fireflies
# Casablanca
# ...

# %%
import pandas

# %%
pandas.json_normalize(data)
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96            Reservoir Dogs
# 96    97                     Ikiru
# 97    98        Lawrence of Arabia
# 98    99              Citizen Kane
# 99   100                         M
#
#                                           description  \
# 0   Two imprisoned men bond over a number of years...
# 1   The aging patriarch of an organized crime dyna...
# 2   When the menace known as the Joker wreaks havo...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# ..                                                ...
# 95  When a simple jewelry heist goes horribly wron...
# 96  A bureaucrat tries to find meaning in his life...
# ...

# %%
import requests

url = "https://movies-ratings2.p.rapidapi.com/ratings"

querystring = {"id":"tt0111161"}

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "movies-ratings2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'tmdbId': 278, 'imdbId': 'tt0111161', 'lastUpdated': 1738173381282, 'ratings': {'imdb': {'score': 9.3, 'reviewsCount': 3000000, 'url': 'https://www.imdb.com/title/tt0111161/'}, 'metacritic': {'metascore': 82, 'userScore': 9.3, 'averageScore': 8.8, 'url': 'https://www.metacritic.com/movie/the-shawshank-redemption'}, 'rotten_tomatoes': {'tomatometer': 89, 'tomatometerReviewsCount': 146, 'audienceScore': 98, 'audienceScoreReviewsCount': 250000, 'averageScore': 9.4, 'url': 'https://www.rottentomatoes.com/m/shawshank_redemption'}, 'letterboxd': {'score': 4.6, 'url': 'https://letterboxd.com/film/the-shawshank-redemption'}, 'allocine': None, 'average': {'score': 9.12}}, 'media': {'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'budget': 25000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 278, 'imdb_id': 'tt0111161', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisone
# ...

# %%
data = response.json()

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['tmdbId', 'imdbId', 'lastUpdated', 'ratings', 'media'])

# %%
len(data['media'])
# Out:
# 23

# %%
data['media'].keys()
# Out:
# dict_keys(['backdrop_path', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'external_ids', 'director', 'media_type'])

# %%
data['media']["original_title"]
# Out:
# 'The Shawshank Redemption'

# %%
pandas.json_normalize(data['media'])
# Out:
#                       backdrop_path    budget  \
# 0  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  25000000
#
#                                               genres homepage   id    imdb_id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           278  tt0111161
#
#   origin_country original_language            original_title  \
# 0           [US]                en  The Shawshank Redemption
#
#                                             overview  ...  \
# 0  Imprisoned in the 1940s for the double murder ...  ...
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
#
#                       title  video        director  media_type  \
# 0  The Shawshank Redemption  False  Frank Darabont       movie
#
#   external_ids.imdb_id external_ids.wikidata_id external_ids.facebook_id  \
# 0            tt0111161                  Q172241                     None
#
#   external_ids.instagram_id  external_ids.twitter_id
# ...

# %%
import requests

url = "https://movie-database-api1.p.rapidapi.com/list_movies.json"

querystring = {"limit":"20","page":"1","quality":"all","genre":"all","minimum_rating":"0","query_term":"0","sort_by":"date_added","order_by":"desc","with_rt_ratings":"false"}

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "movie-database-api1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'ok', 'status_message': 'Query was successful', 'data': {'movie_count': 69457, 'limit': 20, 'page_number': 1, 'movies': [{'id': 70682, 'url': 'https://yts.mx/movies/knights-of-the-round-table-1953', 'imdb_code': 'tt0045966', 'title': 'Knights of the Round Table', 'title_english': 'Knights of the Round Table', 'title_long': 'Knights of the Round Table (1953)', 'slug': 'knights-of-the-round-table-1953', 'year': 1953, 'rating': 6.2, 'runtime': 115, 'genres': ['Action', 'Adventure', 'Drama', 'Romance'], 'summary': '', 'description_full': '', 'synopsis': '', 'yt_trailer_code': 'kya9QyMYbdo', 'language': 'en', 'mpa_rating': '', 'background_image': 'https://yts.mx/assets/images/movies/knights_of_the_round_table_1953/background.jpg', 'background_image_original': 'https://yts.mx/assets/images/movies/knights_of_the_round_table_1953/background.jpg', 'small_cover_image': 'https://yts.mx/assets/images/movies/knights_of_the_round_table_1953/small-cover.jpg', 'medium_cover_image': 'https
# ...

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['status', 'status_message', 'data', '@meta'])

# %%
data["data"].keys()
# Out:
# dict_keys(['movie_count', 'limit', 'page_number', 'movies'])

# %%
pandas.json_normalize(data["data"]['movies'])
# Out:
#        id                                                url   imdb_code  \
# 0   70682  https://yts.mx/movies/knights-of-the-round-tab...   tt0045966
# 1   70681                  https://yts.mx/movies/harlow-1965   tt0059253
# 2   70680                https://yts.mx/movies/the-reef-2006   tt0820142
# 3   70679                 https://yts.mx/movies/whisper-2007   tt0435528
# 4   70678          https://yts.mx/movies/butterfly-kiss-1995   tt0112604
# 5   70677       https://yts.mx/movies/the-colors-within-2024  tt23951384
# 6   70676  https://yts.mx/movies/slaughters-big-rip-off-1973   tt0070706
# 7   70675     https://yts.mx/movies/songs-from-the-hole-2024  tt30835190
# 8   70674                   https://yts.mx/movies/fixed-2025   tt8785038
# 9   70673      https://yts.mx/movies/the-kid-from-texas-1950   tt0042638
# 10  70672        https://yts.mx/movies/the-last-goodbye-2025  tt33112363
# 11  70671      https://yts.mx/movies/great-white-waters-2025  tt37025253
# ...

# %%
print("GET", "POST", "PUT/PATCH", "DELETE")
# Out:
# GET POST PUT/PATCH DELETE

# %%
import http.client

conn = http.client.HTTPSConnection("zillow56.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
    'x-rapidapi-host': "zillow56.p.rapidapi.com"
}

conn.request("GET", "/search?location=houston%2C%20tx&output=json&status=forSale&sortSelection=priorityscore&listing_type=by_agent&doz=any", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"results":[{"bathrooms":4.0,"bedrooms":4.0,"city":"Houston","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/d62fc99e164b92ad2fdfccd3a28ddafa-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isShowcaseListing":true,"isUnmappable":false,"isZillowOwned":false,"latitude":29.79335,"listing_sub_type":{"is_FSBA":true},"livingArea":3693.0,"longitude":-95.51273,"lotAreaUnit":"sqft","lotAreaValue":5305.608,"price":1000000.0,"priceForHDP":1000000.0,"rentZestimate":5689,"shouldHighlight":false,"state":"TX","streetAddress":"26 Windsor Ct","taxAssessedValue":822161.0,"timeOnZillow":299268000,"zestimate":976300,"zipcode":"77055","zpid":97665206},{"bathrooms":3.0,"bedrooms":2.0,"city":"Houston","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"
# ...

# %%
import json

# %%
data = json.loads(data.decode("utf-8"))

# %%
res.status
# Out:
# 200

# %%
print(res.headers)
# Out:
# Date: Mon, 18 Aug 2025 07:38:38 GMT
# Content-Type: application/json
# Content-Length: 35142
# Connection: keep-alive
# X-RateLimit-rapid-free-plans-hard-limit-Limit: 500000
# X-RateLimit-rapid-free-plans-hard-limit-Remaining: 499999
# X-RateLimit-rapid-free-plans-hard-limit-Reset: 2678332
# X-RateLimit-Requests-Limit: 30
# X-RateLimit-Requests-Remaining: 29
# X-RateLimit-Requests-Reset: 2678332
# Server: RapidAPI-1.2.8
# X-RapidAPI-Version: 1.2.8
# X-RapidAPI-Region: AWS - ap-southeast-1
# X-RapidAPI-Request-Id: 51b8c16cb6e54f7d5a281a51229050c23cc6ad777ecd208ff8c65810da1598e7

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['results', 'resultsPerPage', 'totalPages', 'totalResultCount'])

# %%
import pandas

# %%
pandas.json_normalize(data['results'])
# Out:
#     bathrooms  bedrooms      city country currency  daysOnZillow homeStatus  \
# 0         4.0       4.0   Houston     USA      USD            -1   FOR_SALE
# 1         3.0       2.0   Houston     USA      USD            -1   FOR_SALE
# 2         3.0       4.0   Houston     USA      USD            -1   FOR_SALE
# 3         3.0       4.0   Houston     USA      USD            -1   FOR_SALE
# 4         5.0       5.0   Houston     USA      USD            -1   FOR_SALE
# 5         2.0       3.0   Houston     USA      USD            -1   FOR_SALE
# 6         3.0       5.0   Houston     USA      USD            -1   FOR_SALE
# 7         6.0       4.0   Houston     USA      USD            -1   FOR_SALE
# 8         4.0       5.0   Houston     USA      USD            -1   FOR_SALE
# 9         3.0       4.0   Houston     USA      USD            -1   FOR_SALE
# 10        3.0       3.0   Houston     USA      USD            -1   FOR_SALE
# ...
